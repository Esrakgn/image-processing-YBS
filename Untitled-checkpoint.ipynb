# %%
import instaloader

# %%
def download_profile_pic_hd(target_username):
    L = instaloader.Instaloader(
        download_pictures=False,
        download_videos=False,
        download_video_thumbnails=False,
        download_geotags=False,
        download_comments=False,
        save_metadata=False,
        compress_json=False
    )
    
    profile = instaloader.Profile.from_username(L.context, target_username)
    L.download_profilepic(profile)
    print(f"✔ {target_username} profil fotoğrafı indirildi.")

download_profile_pic_hd("pirozkan")
# Out:
# pirozkan\2024-04-03_07-35-12_UTC_profile_pic.jpg
# ✔ pirozkan profil fotoğrafı indirildi.
